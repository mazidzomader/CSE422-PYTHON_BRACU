# %% [markdown]
# <a href="https://colab.research.google.com/github/mazidzomader/CSE422-PYTHON_BRACU/blob/main/CSE422_Project_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd

# %% [markdown]
# ## Import Dataset

# %%
url = "https://github.com/mazidzomader/CSE422-Project-Academic_Success_Analysis/blob/main/Dataset/academic_success_dataset.csv?raw=true"

df = pd.read_csv(url)
display(df.head())
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0             1.0              17.0                5.0   171.0
# 1             1.0              15.0                1.0  9254.0
# 2             1.0               NaN                5.0  9070.0
# 3             1.0              17.0                2.0  9773.0
# 4             2.0              39.0                1.0  8014.0
#
#    Daytime/evening attendance\t  Previous qualification  \
# 0                           1.0                     1.0
# 1                           1.0                     1.0
# 2                           1.0                     1.0
# 3                           1.0                     1.0
# 4                           0.0                     1.0
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           122.0          1.0                    19.0
# 1                           160.0          1.0                     1.0
# ...
